# %%
import pandas as pd
import re

# %%
file_path = './data/health insurance coverage by age.csv'
df = pd.read_csv(file_path)

# %%
# Delete the first column
new_df = df.drop(df.columns[0], axis=1)

# Get the columns to keep (every other column)
columns_to_keep = new_df.columns[::2]

# Keep only the columns to keep and create a new DataFrame

new_df = new_df[columns_to_keep]

# Display the DataFrame with every other column deleted
print("\nDataFrame with every other column deleted:")
print(new_df)
# Out:
# DataFrame with every other column deleted:
#     Block Group 1, Census Tract 702, Montgomery County, New York!!Estimate  \
# 0                                                 435
# 1                                                  72
# 2                                                  72
# 3                                                  43
# 4                                                   0
# ..                                                ...
# 61                                                  0
# 62                                                  0
# 63                                                  0
# 64                                                 22
# 65                                                  0
#
#     Block Group 2, Census Tract 702, Montgomery County, New York!!Estimate  \
# 0                                                 871
# 1                                                 372
# 2                                                 340
# 3                                                  19
# 4                                                   0
# ..                                                ...
# 61                                                 67
# 62                                                  0
# 63                                                 24
# 64                                                 41
# 65                                                  0
#
#     Block Group 3, Census Tract 702, Montgomery County, New York!!Estimate  \
# 0                                                 615
# 1                                                 139
# 2                                                  77
# 3                                                   9
# 4                                                   0
# ..                                                ...
# 61                                                  0
# 62                                                  0
# 63                                                  0
# 64                                                 21
# 65                                                  0
#
#     Block Group 1, Census Tract 703, Montgomery County, New York!!Estimate  \
# 0                                                 853
# 1                                                 187
# 2                                                 187
# 3                                                  29
# 4                                                   0
# ..                                                ...
# 61                                                 10
# 62                                                  0
# 63                                                  0
# 64                                                  0
# 65                                                  0
#
#    Block Group 2, Census Tract 703, Montgomery County, New York!!Estimate  \
# 0                                               1,216
# 1                                                 341
# 2                                                 333
# 3                                                  34
# 4                                                   0
# ..                                                ...
# 61                                                 25
# 62                                                  0
# 63                                                  6
# 64                                                 27
# 65                                                  0
#
#     Block Group 1, Census Tract 704, Montgomery County, New York!!Estimate  \
# 0                                                 647
# 1                                                 161
# 2                                                 145
# 3                                                  73
# 4                                                   8
# ..                                                ...
# 61                                                  0
# 62                                                  0
# 63                                                  0
# 64                                                 14
# 65                                                  0
#
#    Block Group 2, Census Tract 704, Montgomery County, New York!!Estimate  \
# 0                                               1,644
# 1                                                 405
# 2                                                 378
# 3                                                 138
# 4                                                  36
# ..                                                ...
# 61                                                 18
# 62                                                  0
# 63                                                  0
# 64                                                 48
# 65                                                  0
#
#    Block Group 1, Census Tract 705, Montgomery County, New York!!Estimate  \
# 0                                               1,361
# 1                                                 377
# 2                                                 371
# 3                                                 124
# 4                                                   0
# ..                                                ...
# 61                                                 17
# 62                                                  0
# 63                                                  0
# 64                                                  6
# 65                                                  0
#
#    Block Group 2, Census Tract 705, Montgomery County, New York!!Estimate  \
# 0                                               1,134
# 1                                                 220
# 2                                                 217
# 3                                                 160
# 4                                                   4
# ..                                                ...
# 61                                                 15
# 62                                                  0
# 63                                                  0
# 64                                                 39
# 65                                                  0
#
#    Block Group 1, Census Tract 706, Montgomery County, New York!!Estimate  \
# 0                                               1,063
# 1                                                 301
# 2                                                 301
# 3                                                   0
# 4                                                  12
# ..                                                ...
# 61                                                 32
# 62                                                  0
# 63                                                  0
# 64                                                  9
# 65                                                  0
#
#     ...  \
# 0   ...
# 1   ...
# 2   ...
# 3   ...
# 4   ...
# ..  ...
# 61  ...
# 62  ...
# 63  ...
# 64  ...
# 65  ...
#
#    Block Group 2, Census Tract 726, Montgomery County, New York!!Estimate  \
# 0                                               1,228
# 1                                                 360
# 2                                                 339
# 3                                                  89
# 4                                                 103
# ..                                                ...
# 61                                                  5
# 62                                                  0
# 63                                                  0
# 64                                                 40
# 65                                                  0
#
#    Block Group 3, Census Tract 726, Montgomery County, New York!!Estimate  \
# 0                                               1,181
# 1                                                 551
# 2                                                 175
# 3                                                 123
# 4                                                  47
# ..                                                ...
# 61                                                  0
# 62                                                  0
# 63                                                  0
# 64                                                  9
# 65                                                  0
#
#    Block Group 1, Census Tract 727, Montgomery County, New York!!Estimate  \
# 0                                                 876
# 1                                                 235
# 2                                                 223
# 3                                                 143
# 4                                                  10
# ..                                                ...
# 61                                                 22
# 62                                                  0
# 63                                                  0
# 64                                                 13
# 65                                                  0
#
#    Block Group 2, Census Tract 727, Montgomery County, New York!!Estimate  \
# 0                                               1,171
# 1                                                 436
# 2                                                 220
# 3                                                 183
# 4                                                  11
# ..                                                ...
# 61                                                  4
# 62                                                  0
# 63                                                  0
# 64                                                 10
# 65                                                  0
#
#    Block Group 3, Census Tract 727, Montgomery County, New York!!Estimate  \
# 0                                               1,385
# 1                                                 392
# 2                                                 240
# 3                                                  93
# 4                                                  23
# ..                                                ...
# 61                                                 18
# 62                                                  0
# 63                                                  3
# 64                                                 22
# 65                                                  9
#
#    Block Group 4, Census Tract 727, Montgomery County, New York!!Estimate  \
# 0                                                 972
# 1                                                 277
# 2                                                 251
# 3                                                 106
# 4                                                  30
# ..                                                ...
# 61                                                  3
# 62                                                  0
# 63                                                  0
# 64                                                 29
# 65                                                  0
#
#    Block Group 1, Census Tract 728, Montgomery County, New York!!Estimate  \
# 0                                               1,095
# 1                                                 130
# 2                                                 130
# 3                                                  71
# 4                                                  40
# ..                                                ...
# 61                                                 23
# 62                                                  0
# 63                                                  1
# 64                                                 22
# 65                                                  0
#
#    Block Group 2, Census Tract 728, Montgomery County, New York!!Estimate  \
# 0                                               1,150
# 1                                                 338
# 2                                                 309
# 3                                                 221
# 4                                                   0
# ..                                                ...
# 61                                                 14
# 62                                                  0
# 63                                                  0
# 64                                                  7
# 65                                                  0
#
#     Block Group 3, Census Tract 728, Montgomery County, New York!!Estimate  \
# 0                                                 678
# 1                                                  81
# 2                                                  81
# 3                                                  72
# 4                                                   0
# ..                                                ...
# 61                                                  0
# 62                                                  0
# 63                                                  2
# 64                                                 12
# 65                                                  0
#
#    Block Group 4, Census Tract 728, Montgomery County, New York!!Estimate
# 0                                               1,095
# 1                                                 227
# 2                                                 191
# 3                                                 131
# 4                                                   0
# ..                                                ...
# 61                                                  0
# 62                                                  0
# 63                                                  0
# 64                                                 50
# 65                                                  0
#
# [66 rows x 43 columns]

# %%
# Convert rows containing string values to float
for column in new_df.columns:
    new_df[column] = pd.to_numeric(new_df[column], errors='coerce', downcast='integer')

# Rows to compute sum for
specific_rows = [[1, 17, 33], [6, 22, 38], [3, 4, 19, 20, 35, 36]]

# Create a new DataFrame to store the sums of specific rows for each column
sums_df = pd.DataFrame(columns=new_df.columns)

# Iterate through each column and calculate the sum for specific rows
for i, specific_row in enumerate(specific_rows):
    for column in new_df.columns:
        sum_values = new_df.iloc[specific_row, :][column].sum()
        sums_df.at[i, column] = int(sum_values)

# Display the sum_df DataFrame
print(sums_df)
# Out:
#   Block Group 1, Census Tract 702, Montgomery County, New York!!Estimate  \
# 0                                                316
# 1                                                 50
# 2                                                237
#
#   Block Group 2, Census Tract 702, Montgomery County, New York!!Estimate  \
# 0                                                677
# 1                                                533
# 2                                                 75
#
#   Block Group 3, Census Tract 702, Montgomery County, New York!!Estimate  \
# 0                                                467
# 1                                                127
# 2                                                203
#
#   Block Group 1, Census Tract 703, Montgomery County, New York!!Estimate  \
# 0                                                796
# 1                                                443
# 2                                                 96
#
#   Block Group 2, Census Tract 703, Montgomery County, New York!!Estimate  \
# 0                                               1013
# 1                                                618
# 2                                                275
#
#   Block Group 1, Census Tract 704, Montgomery County, New York!!Estimate  \
# 0                                                495
# 1                                                 82
# 2                                                266
#
#   Block Group 2, Census Tract 704, Montgomery County, New York!!Estimate  \
# 0                                               1342
# 1                                                390
# 2                                                668
#
#   Block Group 1, Census Tract 705, Montgomery County, New York!!Estimate  \
# 0                                               1164
# 1                                                402
# 2                                                702
#
#   Block Group 2, Census Tract 705, Montgomery County, New York!!Estimate  \
# 0                                                891
# 1                                                 99
# 2                                                638
#
#   Block Group 1, Census Tract 706, Montgomery County, New York!!Estimate  ...  \
# 0                                                936                      ...
# 1                                                449                      ...
# 2                                                411                      ...
#
#   Block Group 2, Census Tract 726, Montgomery County, New York!!Estimate  \
# 0                                               1084
# 1                                                273
# 2                                                481
#
#   Block Group 3, Census Tract 726, Montgomery County, New York!!Estimate  \
# 0                                               1032
# 1                                                 22
# 2                                                418
#
#   Block Group 1, Census Tract 727, Montgomery County, New York!!Estimate  \
# 0                                                746
# 1                                                171
# 2                                                517
#
#   Block Group 2, Census Tract 727, Montgomery County, New York!!Estimate  \
# 0                                               1080
# 1                                                 95
# 2                                                603
#
#   Block Group 3, Census Tract 727, Montgomery County, New York!!Estimate  \
# 0                                               1161
# 1                                                279
# 2                                                542
#
#   Block Group 4, Census Tract 727, Montgomery County, New York!!Estimate  \
# 0                                                802
# 1                                                217
# 2                                                451
#
#   Block Group 1, Census Tract 728, Montgomery County, New York!!Estimate  \
# 0                                                882
# 1                                                 72
# 2                                                678
#
#   Block Group 2, Census Tract 728, Montgomery County, New York!!Estimate  \
# 0                                               1022
# 1                                                 97
# 2                                                777
#
#   Block Group 3, Census Tract 728, Montgomery County, New York!!Estimate  \
# 0                                                553
# 1                                                 27
# 2                                                451
#
#   Block Group 4, Census Tract 728, Montgomery County, New York!!Estimate
# 0                                                960
# 1                                                198
# 2                                                562
#
# [3 rows x 43 columns]

# %%
# Replace column names with geo_ids format
geo_ids = []

for column in sums_df.columns:
    arr = column.split(',')

    # Extract numeric values using regex
    census_tract = re.findall(r"[-+]?\d*\.\d+|\d+", arr[1])[0]
    block_group = re.findall(r"[-+]?\d*\.\d+|\d+", arr[0])[0]

    val = '0' + census_tract + '00' + block_group
    geo_ids.append(val)

# Flip the DataFrame matrix
sums_df_flip = sums_df.transpose()

# Add geo_ids to the flipped data as a new column
sums_df_flip.columns = ["total", "medicaid", "private"]
sums_df_flip["geo_id"] = geo_ids
    
# sums_df.columns = []
print(sums_df_flip)
# Out:
#                                                    total medicaid private  \
# Block Group 1, Census Tract 702, Montgomery Cou...   316       50     237
# Block Group 2, Census Tract 702, Montgomery Cou...   677      533      75
# Block Group 3, Census Tract 702, Montgomery Cou...   467      127     203
# Block Group 1, Census Tract 703, Montgomery Cou...   796      443      96
# Block Group 2, Census Tract 703, Montgomery Cou...  1013      618     275
# Block Group 1, Census Tract 704, Montgomery Cou...   495       82     266
# Block Group 2, Census Tract 704, Montgomery Cou...  1342      390     668
# Block Group 1, Census Tract 705, Montgomery Cou...  1164      402     702
# Block Group 2, Census Tract 705, Montgomery Cou...   891       99     638
# Block Group 1, Census Tract 706, Montgomery Cou...   936      449     411
# Block Group 2, Census Tract 706, Montgomery Cou...  1171      487     493
# Block Group 1, Census Tract 707, Montgomery Cou...   947      266     530
# Block Group 2, Census Tract 707, Montgomery Cou...  1082      191     807
# Block Group 1, Census Tract 708, Montgomery Cou...  1135      844     238
# Block Group 2, Census Tract 708, Montgomery Cou...  1528      589     682
# Block Group 1, Census Tract 709, Montgomery Cou...   998      516     316
# Block Group 1, Census Tract 721, Montgomery Cou...   981      241     606
# Block Group 2, Census Tract 721, Montgomery Cou...  1300      317     877
# Block Group 3, Census Tract 721, Montgomery Cou...   456      104     278
# Block Group 4, Census Tract 721, Montgomery Cou...  1324      340     928
# Block Group 1, Census Tract 722, Montgomery Cou...   621        9     515
# Block Group 2, Census Tract 722, Montgomery Cou...   620      100     504
# Block Group 3, Census Tract 722, Montgomery Cou...   814      165     520
# Block Group 4, Census Tract 722, Montgomery Cou...   772      146     437
# Block Group 1, Census Tract 723, Montgomery Cou...  1118      205     599
# Block Group 2, Census Tract 723, Montgomery Cou...  1225      351     586
# Block Group 1, Census Tract 724, Montgomery Cou...   802      359     347
# Block Group 2, Census Tract 724, Montgomery Cou...  1167      504     532
# Block Group 1, Census Tract 725, Montgomery Cou...   944      398     151
# Block Group 2, Census Tract 725, Montgomery Cou...   611      176     254
# Block Group 3, Census Tract 725, Montgomery Cou...   833       85     713
# Block Group 4, Census Tract 725, Montgomery Cou...  1288      469     564
# Block Group 1, Census Tract 726, Montgomery Cou...  1022      158     657
# Block Group 2, Census Tract 726, Montgomery Cou...  1084      273     481
# Block Group 3, Census Tract 726, Montgomery Cou...  1032       22     418
# Block Group 1, Census Tract 727, Montgomery Cou...   746      171     517
# Block Group 2, Census Tract 727, Montgomery Cou...  1080       95     603
# Block Group 3, Census Tract 727, Montgomery Cou...  1161      279     542
# Block Group 4, Census Tract 727, Montgomery Cou...   802      217     451
# Block Group 1, Census Tract 728, Montgomery Cou...   882       72     678
# Block Group 2, Census Tract 728, Montgomery Cou...  1022       97     777
# Block Group 3, Census Tract 728, Montgomery Cou...   553       27     451
# Block Group 4, Census Tract 728, Montgomery Cou...   960      198     562
#
#                                                      geo_id
# Block Group 1, Census Tract 702, Montgomery Cou...  0702001
# Block Group 2, Census Tract 702, Montgomery Cou...  0702002
# Block Group 3, Census Tract 702, Montgomery Cou...  0702003
# Block Group 1, Census Tract 703, Montgomery Cou...  0703001
# Block Group 2, Census Tract 703, Montgomery Cou...  0703002
# Block Group 1, Census Tract 704, Montgomery Cou...  0704001
# Block Group 2, Census Tract 704, Montgomery Cou...  0704002
# Block Group 1, Census Tract 705, Montgomery Cou...  0705001
# Block Group 2, Census Tract 705, Montgomery Cou...  0705002
# Block Group 1, Census Tract 706, Montgomery Cou...  0706001
# Block Group 2, Census Tract 706, Montgomery Cou...  0706002
# Block Group 1, Census Tract 707, Montgomery Cou...  0707001
# Block Group 2, Census Tract 707, Montgomery Cou...  0707002
# Block Group 1, Census Tract 708, Montgomery Cou...  0708001
# Block Group 2, Census Tract 708, Montgomery Cou...  0708002
# Block Group 1, Census Tract 709, Montgomery Cou...  0709001
# Block Group 1, Census Tract 721, Montgomery Cou...  0721001
# Block Group 2, Census Tract 721, Montgomery Cou...  0721002
# Block Group 3, Census Tract 721, Montgomery Cou...  0721003
# Block Group 4, Census Tract 721, Montgomery Cou...  0721004
# Block Group 1, Census Tract 722, Montgomery Cou...  0722001
# Block Group 2, Census Tract 722, Montgomery Cou...  0722002
# Block Group 3, Census Tract 722, Montgomery Cou...  0722003
# Block Group 4, Census Tract 722, Montgomery Cou...  0722004
# Block Group 1, Census Tract 723, Montgomery Cou...  0723001
# Block Group 2, Census Tract 723, Montgomery Cou...  0723002
# Block Group 1, Census Tract 724, Montgomery Cou...  0724001
# Block Group 2, Census Tract 724, Montgomery Cou...  0724002
# Block Group 1, Census Tract 725, Montgomery Cou...  0725001
# Block Group 2, Census Tract 725, Montgomery Cou...  0725002
# Block Group 3, Census Tract 725, Montgomery Cou...  0725003
# Block Group 4, Census Tract 725, Montgomery Cou...  0725004
# Block Group 1, Census Tract 726, Montgomery Cou...  0726001
# Block Group 2, Census Tract 726, Montgomery Cou...  0726002
# Block Group 3, Census Tract 726, Montgomery Cou...  0726003
# Block Group 1, Census Tract 727, Montgomery Cou...  0727001
# Block Group 2, Census Tract 727, Montgomery Cou...  0727002
# Block Group 3, Census Tract 727, Montgomery Cou...  0727003
# Block Group 4, Census Tract 727, Montgomery Cou...  0727004
# Block Group 1, Census Tract 728, Montgomery Cou...  0728001
# Block Group 2, Census Tract 728, Montgomery Cou...  0728002
# Block Group 3, Census Tract 728, Montgomery Cou...  0728003
# Block Group 4, Census Tract 728, Montgomery Cou...  0728004

# %%
# File path where you want to save the CSV file
output_file_path = './data/outputs/health_insurance_estimates.csv'

# Export 'result_df' DataFrame to a CSV file
sums_df_flip.to_csv(output_file_path, index=False)

print(f"CSV file '{output_file_path}' has been created.")
# Out:
# CSV file './data/outputs/health_insurance_estimates.csv' has been created.
